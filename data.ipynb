# %%
import pandas as pd
import matplotlib as mpl

# %%
# Load and organize data
stocks = pd.read_csv('2018_Financial_Data.csv')
new_columns = stocks.columns.values
new_columns[0] = "Ticker"
stocks.columns = new_columns
stocks.set_index('Ticker', inplace=True)

stocks.shape
# Out:
# (4392, 224)

# %%
# Test indexing
stocks.loc['NFLX']
# Out:
# Revenue                          15794341000.0
# Revenue Growth                          0.3508
# Cost of Revenue                   9967538000.0
# Gross Profit                      5826803000.0
# R&D Expenses                      1221814000.0
#                                  ...
# R&D Expense Growth                      0.2811
# SG&A Expenses Growth                    0.6065
# Sector                  Communication Services
# 2019 PRICE VAR [%]                   20.888442
# Class                                        1
# Name: NFLX, Length: 224, dtype: object

# %%
# grab companies with over 10 billion market cap
stocks.loc[stocks['Market Cap'] > 10000000000]
# Out:
#              Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# Ticker
# CMCSA   9.450700e+10          0.1115     0.000000e+00  9.450700e+10
# KMI     1.414400e+10          0.0320     7.288000e+09  6.856000e+09
# INTC    7.084800e+10          0.1289     2.711100e+10  4.373700e+10
# MU      3.039100e+10          0.4955     1.250000e+10  1.789100e+10
# GE      1.216150e+11          0.0285     9.546100e+10  2.615400e+10
# ...              ...             ...              ...           ...
# CHT     7.041928e+09         -0.0807     4.560294e+09  2.481634e+09
# SHG     5.694793e+09         -0.0381     0.000000e+00  5.694793e+09
# IEP     1.177700e+10         -0.0667     8.947000e+09  2.830000e+09
# IX      2.504086e+10          0.0357     1.743905e+10  7.601807e+09
# IGLD    2.478989e+09         -0.1207     0.000000e+00  2.478989e+09
#
#         R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# Ticker
# ...

# %%
# test plot
stocks.iloc[:4].plot(x='Revenue', y='Market Cap')
# Out:
# <AxesSubplot:xlabel='Revenue'>
