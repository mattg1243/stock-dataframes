# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load and organize data
nflxOG = pd.read_csv('./netflix.csv', parse_dates=True, index_col='Date')
nflx = nflxOG['2017-01-01':]
nflx.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1202.000000  1202.000000  1202.000000  1202.000000  1.202000e+03
# mean    355.949367   345.366032   350.721947   350.861763  7.540511e+06
# std     131.595228   127.888469   129.677863   129.756415  5.004420e+06
# min     128.190002   124.309998   124.959999   127.489998  1.144000e+06
# 25%     273.522514   263.302505   267.427505   267.629997  4.400400e+06
# 50%     354.000000   342.850006   348.284988   349.145004  6.005800e+06
# 75%     488.857498   477.457504   482.615005   482.799995  9.104225e+06
# max     646.840027   630.859985   642.229980   639.099976  5.841040e+07
#
#          Adj Close
# count  1202.000000
# mean    350.861763
# std     129.756415
# min     127.489998
# 25%     267.629997
# 50%     349.145004
# 75%     482.799995
# max     639.099976

# %%
# create plot
plt.figure(figsize=(12, 6))
plt.title("NFLX Daily Chart")
# plt.plot(nflx['Close'], nflx)
nflx['Close'].plot()
# Out:
# <AxesSubplot:title={'center':'NFLX Daily Chart'}, xlabel='Date'>
